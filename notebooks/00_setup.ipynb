# %% [markdown]
# # 00 — Setup & Configuration
#
# **But** : préparer l'environnement, monter Google Drive, installer les dépendances, vérifier les imports et configurer les chemins.
#
# > Ce notebook est le **point d'entrée**. Exécutez-le une seule fois après chaque redémarrage de runtime.
#
# > Aucune variable de ce notebook n'est nécessaire aux notebooks suivants : chaque notebook recharge sa propre config depuis le disque.

# %% [markdown]
# ## 1. Monter Google Drive (Colab uniquement)

# %%
# Cette cellule ne fait rien en local — elle monte Drive uniquement dans Colab.
try:
    from google.colab import drive
    drive.mount('/content/drive')
    # %cd /content/drive/MyDrive/LAAFI_AI
    print('Google Drive monté avec succès.')
except ImportError:
    print('Pas dans Colab — exécution locale détectée.')

# %% [markdown]
# ## 2. Installer les dépendances

# %%
# %%capture
# %pip install -q -r requirements-colab.txt

# %% [markdown]
# ## 3. Configurer le chemin du projet

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))
print('Project root:', PROJECT_ROOT)

# %% [markdown]
# ## 4. Vérifier les imports principaux

# %%
import torch
print('PyTorch version:', torch.__version__)
print('CUDA disponible:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

from laafi_ai.config import ExperimentConfig
from laafi_ai.paths import resolve_project_paths, is_colab
print('\nEnvironment: ', 'Google Colab' if is_colab() else 'Local')
print('Tous les imports OK ✓')

# %% [markdown]
# ## 5. Charger la config et résoudre les chemins

# %%
config = ExperimentConfig.from_yaml('configs/default.yaml')
paths = resolve_project_paths(config, project_root=PROJECT_ROOT)

print('\n--- Répertoires créés ---')
print('  Checkpoints:', paths.checkpoint_dir)
print('  Metrics:    ', paths.metrics_dir)
print('  Figures:    ', paths.figures_dir)
print('  Predictions:', paths.predictions_dir)
print('  Reports:    ', paths.reports_dir)

# %% [markdown]
# ## 6. Fixer la graine aléatoire

# %%
from laafi_ai.cli_train import set_seed
set_seed(config.seed)
print(f'Seed fixée à {config.seed} ✓')

# %% [markdown]
# ---
# **Prochain notebook** : `01_data_prep.ipynb` pour charger et vérifier les données.
